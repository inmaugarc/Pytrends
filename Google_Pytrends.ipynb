# %%
trends.build_payload(kw_list=["Electric Car"])
data = trends.interest_by_region()
data = data.sort_values(by="Electric Car", ascending=False)
data = data.head(10)
print(data)
# Out:
#                       Electric Car
# geoName
# United Kingdom                 100
# Ireland                         86
# New Zealand                     67
# Canada                          58
# Nepal                           55
# Australia                       50
# United States                   45
# Singapore                       39
# Sri Lanka                       38
# United Arab Emirates            35

# %%
data.reset_index().plot(x="geoName", y="Electric Car", 
                        figsize=(20,15), kind="bar",color="green")
plt.style.use('fivethirtyeight')
plt.show()

# %%
data = TrendReq(hl='en-US', tz=360)
data.build_payload(kw_list=['Electric Car'])
data = data.interest_over_time()
fig, ax = plt.subplots(figsize=(20, 15))
data['Electric Car'].plot(color="green")
plt.style.use('fivethirtyeight')
plt.title('Total Google Searches for Electric Car', fontweight='bold')
plt.xlabel('Year')
plt.ylabel('Total Count')
plt.show()

# %%
trends.build_payload(kw_list=["Data Licensing"])
data = trends.interest_by_region()
data = data.sort_values(by="Data Licensing", ascending=False)
data = data.head(10)
print(data)
# Out:
#                           Data Licensing
# geoName
# United Kingdom                       100
# Australia                             82
# United States                         74
# India                                 36
# Afghanistan                            0
# Norway                                 0
# Palau                                  0
# Pakistan                               0
# Oman                                   0
# Northern Mariana Islands               0

# %%
data.reset_index().plot(x="geoName", y="Data Licensing", 
                        figsize=(20,15), kind="bar")
plt.style.use('fivethirtyeight')
plt.show()

# %%
data = TrendReq(hl='en-US', tz=360)
data.build_payload(kw_list=['Data Licensing'])
data = data.interest_over_time()
fig, ax = plt.subplots(figsize=(20, 15))
data['Data Licensing'].plot()
plt.style.use('fivethirtyeight')
plt.title('Total Google Searches for Data Licensing', fontweight='bold')
plt.xlabel('Year')
plt.ylabel('Total Count')
plt.show()

# %%
trends.build_payload(kw_list=["AWS"])
data = trends.interest_by_region()
data = data.sort_values(by="AWS", ascending=False)
data = data.head(10)
print(data)
# Out:
#              AWS
# geoName
# China        100
# Singapore     50
# South Korea   43
# St. Helena    42
# Ireland       42
# Japan         29
# Australia     28
# Israel        28
# Hong Kong     25
# New Zealand   24

# %%
data.reset_index().plot(x="geoName", y="AWS", 
                        figsize=(20,15), kind="bar")
plt.style.use('fivethirtyeight')
plt.show()

# %%
data = TrendReq(hl='en-US', tz=360)
data.build_payload(kw_list=['AWS'])
data = data.interest_over_time()
fig, ax = plt.subplots(figsize=(20, 15))
data['AWS'].plot()
plt.style.use('fivethirtyeight')
plt.title('Total Google Searches for AWS', fontweight='bold')
plt.xlabel('Year')
plt.ylabel('Total Count')
plt.show()

# %%
trends.build_payload(kw_list=["Data Driven"])
data = trends.interest_by_region()
data = data.sort_values(by="Data Driven", ascending=False)
data = data.head(10)
print(data)
# Out:
#                Data Driven
# geoName
# China                  100
# St. Helena              78
# Singapore               59
# New Zealand             40
# Netherlands             37
# Hong Kong               35
# India                   34
# South Africa            32
# United States           30
# Australia               29

# %%
data.reset_index().plot(x="geoName", y="Data Driven", 
                        figsize=(20,15), kind="bar")
plt.style.use('fivethirtyeight')
plt.show()

# %%
data = TrendReq(hl='en-US', tz=360)
data.build_payload(kw_list=['Data Driven'])
data = data.interest_over_time()
fig, ax = plt.subplots(figsize=(20, 15))
data['Data Driven'].plot()
plt.style.use('fivethirtyeight')
plt.title('Total Google Searches for Data Driven', fontweight='bold')
plt.xlabel('Year')
plt.ylabel('Total Count')
plt.show()

# %%
trends.build_payload(kw_list=["COVID"])
data = trends.interest_by_region()
data = data.sort_values(by="COVID", ascending=False)
data = data.head(10)
print(data)
# Out:
#                 COVID
# geoName
# Canada            100
# Portugal           73
# Ireland            69
# El Salvador        58
# France             56
# New Zealand        55
# Italy              53
# United Kingdom     51
# Singapore          49
# Australia          48

# %%
data.reset_index().plot(x="geoName", y="COVID", 
                        figsize=(20,15), kind="bar")
plt.style.use('fivethirtyeight')
plt.show()

# %%
data = TrendReq(hl='en-US', tz=360)
data.build_payload(kw_list=['COVID'])
data = data.interest_over_time()
fig, ax = plt.subplots(figsize=(20, 15))
data['COVID'].plot()
plt.style.use('fivethirtyeight')
plt.title('Total Google Searches for COVID', fontweight='bold')
plt.xlabel('Year')
plt.ylabel('Total Count')
plt.show()

# %%
trends.build_payload(kw_list=["ROBLOX"])
data = trends.interest_by_region()
data = data.sort_values(by="ROBLOX", ascending=False)
data = data.head(10)
print(data)
# Out:
#              ROBLOX
# geoName
# Philippines     100
# Peru             37
# Georgia          27
# Ecuador          21
# Lithuania        14
# Thailand         13
# Colombia         12
# Estonia          12
# New Zealand      12
# Latvia           11

# %%
data.reset_index().plot(x="geoName", y="ROBLOX", 
                        figsize=(20,15), kind="bar")
plt.style.use('fivethirtyeight')
plt.show()

# %%
data = TrendReq(hl='en-US', tz=360)
data.build_payload(kw_list=['ROBLOX'])
data = data.interest_over_time()
fig, ax = plt.subplots(figsize=(20, 15))
data['ROBLOX'].plot()
plt.style.use('fivethirtyeight')
plt.title('Total Google Searches for ROBLOX', fontweight='bold')
plt.xlabel('Year')
plt.ylabel('Total Count')
plt.show()

# %%
trends.build_payload(kw_list=["ROSALIA"])
data = trends.interest_by_region()
data = data.sort_values(by="ROSALIA", ascending=False)
data = data.head(10)
print(data)
# Out:
#                     ROSALIA
# geoName
# Spain                   100
# Cuba                     64
# Guatemala                28
# Indonesia                28
# Honduras                 26
# Paraguay                 24
# Panama                   24
# Bolivia                  24
# Dominican Republic       23
# Ecuador                  23

# %%
data.reset_index().plot(x="geoName", y="ROSALIA", 
                        figsize=(20,15), kind="bar")
plt.style.use('fivethirtyeight')
plt.show()

# %%
data = TrendReq(hl='en-US', tz=360)
data.build_payload(kw_list=['ROSALIA'])
data = data.interest_over_time()
fig, ax = plt.subplots(figsize=(20, 15))
data['ROSALIA'].plot()
plt.style.use('fivethirtyeight')
plt.title('Total Google Searches for ROSALIA', fontweight='bold')
plt.xlabel('Year')
plt.ylabel('Total Count')
plt.show()

# %%
trends.build_payload(kw_list=["CROQUETAS"])
data = trends.interest_by_region()
data = data.sort_values(by="CROQUETAS", ascending=False)
data = data.head(10)
print(data)
# Out:
#                     CROQUETAS
# geoName
# Cuba                      100
# Spain                      97
# Uruguay                    56
# Mexico                     54
# Chile                      32
# Argentina                  28
# Venezuela                  25
# Paraguay                   22
# Bolivia                    18
# Dominican Republic         15

# %%
data.reset_index().plot(x="geoName", y="CROQUETAS", 
                        figsize=(20,15), kind="bar")
plt.style.use('fivethirtyeight')
plt.show()

# %%
data = TrendReq(hl='en-US', tz=360)
data.build_payload(kw_list=['CROQUETAS'])
data = data.interest_over_time()
fig, ax = plt.subplots(figsize=(20, 15))
data['CROQUETAS'].plot()
plt.style.use('fivethirtyeight')
plt.title('Total Google Searches for CROQUETAS', fontweight='bold')
plt.xlabel('Year')
plt.ylabel('Total Count')
plt.show()

# %%
trends.build_payload(kw_list=["MEMES"])
data = trends.interest_by_region()
data = data.sort_values(by="MEMES", ascending=False)
data = data.head(10)
print(data)
# Out:
#              MEMES
# geoName
# El Salvador    100
# Mexico          95
# Guatemala       94
# Bolivia         93
# Honduras        91
# Nicaragua       87
# Paraguay        77
# Peru            73
# Ecuador         66
# Costa Rica      65

# %%
data.reset_index().plot(x="geoName", y="MEMES", 
                        figsize=(20,15), kind="bar")
plt.style.use('fivethirtyeight')
plt.show()

# %%
data = TrendReq(hl='en-US', tz=360)
data.build_payload(kw_list=['MEMES'])
data = data.interest_over_time()
fig, ax = plt.subplots(figsize=(20, 15))
data['MEMES'].plot()
plt.style.use('fivethirtyeight')
plt.title('Total Google Searches for MEMES', fontweight='bold')
plt.xlabel('Year')
plt.ylabel('Total Count')
plt.show()

# %%
trends.build_payload(kw_list=["CUPRA"])
data = trends.interest_by_region()
data = data.sort_values(by="CUPRA", ascending=False)
data = data.head(10)
print(data)
# Out:
#              CUPRA
# geoName
# Réunion        100
# Luxembourg      73
# Spain           55
# Germany         50
# Switzerland     50
# Italy           33
# Portugal        33
# Austria         30
# Slovakia        26
# Algeria         23

# %%
data.reset_index().plot(x="geoName", y="CUPRA", 
                        figsize=(20,15), kind="bar")
plt.style.use('fivethirtyeight')
plt.show()

# %%
data = TrendReq(hl='en-US', tz=360)
data.build_payload(kw_list=['CUPRA'])
data = data.interest_over_time()
fig, ax = plt.subplots(figsize=(20, 15))
data['CUPRA'].plot()
plt.style.use('fivethirtyeight')
plt.title('Total Google Searches for CUPRA', fontweight='bold')
plt.xlabel('Year')
plt.ylabel('Total Count')
plt.show()

# %%
trends.build_payload(kw_list=["Antonio Yachts"])
data = trends.interest_by_region()
data = data.sort_values(by="Antonio Yachts", ascending=False)
data = data.head(10)
print(data)
# Out:
#                           Antonio Yachts
# geoName
# Spain                                100
# Afghanistan                            0
# Paraguay                               0
# Nigeria                                0
# Niue                                   0
# Norfolk Island                         0
# North Korea                            0
# North Macedonia                        0
# Northern Mariana Islands               0
# Norway                                 0

# %%
data.reset_index().plot(x="geoName", y="Antonio Yachts", 
                        figsize=(20,15), kind="bar")
plt.style.use('fivethirtyeight')
plt.show()

# %%
data = TrendReq(hl='en-US', tz=360)
data.build_payload(kw_list=['Antonio Yachts'])
data = data.interest_over_time()
fig, ax = plt.subplots(figsize=(20, 15))
data['Antonio Yachts'].plot()
plt.style.use('fivethirtyeight')
plt.title('Total Google Searches for Antonio Yachts', fontweight='bold')
plt.xlabel('Year')
plt.ylabel('Total Count')
plt.show()
